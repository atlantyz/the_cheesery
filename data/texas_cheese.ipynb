# %%
import pandas as pd

# %%
texas_cheese = pd.read_csv("C:\\Users\\atlan\\Downloads\\texas cheese - Sheet1.csv")

# %%
texas_cheese
# Out:
#                   cheese               company location  price milk type  \
# 0              crescenza    mozzarella company   dallas   9.39       cow
# 1        smoked scamorza    mozzarella company   dallas  15.59       cow
# 2      smoked mozzarella    mozzarella company   dallas  10.79       cow
# 3           queso oaxaca    mozzarella company   dallas  11.99       cow
# 4           queso fresco    mozzarella company   dallas  10.79       cow
# ..                   ...                   ...      ...    ...       ...
# 98                  feta  brazos valley cheese    waco   15.00       cow
# 99        marinated feta  brazos valley cheese    waco   14.00       cow
# 100     marinated labneh  brazos valley cheese    waco   14.00       cow
# 101  mountain maple brie  brazos valley cheese    waco   22.50       cow
# 102         orchard blue  brazos valley cheese    waco   16.50       cow
#
#     country of origin        family         type  texture        color  \
# ...
